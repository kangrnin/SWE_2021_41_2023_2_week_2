# %% [markdown]
# ## Task
# - Complete **isHappy** function following the description below
#
# ### Happy Number
# Write an algorithm to determine if a number **n** is happy.
#
# A **happy number** is a number defined by the following process:
#
# * Starting with any positive integer, replace the number by the sum of the squares of its digits.
# * Repeat the process until the number equals 1 (where it will stay), or it **loops endlessly in a cycle** which does not include 1.
# * Those numbers for which this process **ends in 1** are happy.
#
# Return **true** if n is a happy number, and **false** if not.
#
# Constraints:
# 1 <= n <= $2^{31}$ - 1

# %%
def isHappy(n):
  return isHappy_aux(n, set())

def isHappy_aux(n, visit):
  digit_q_sum = 0
  for digit in str(n):
    digit = int(digit)
    digit_q_sum += digit**2

  n = digit_q_sum
  if n == 1:
    return True
  if n in visit:
    return False

  visit.add(n)
  return isHappy_aux(n, visit)

# %%
for i in range(1, 21):
  print(f'{i} : {isHappy(i)}')
# Out:
# 1 : True
# 2 : False
# 3 : False
# 4 : False
# 5 : False
# 6 : False
# 7 : True
# 8 : False
# 9 : False
# 10 : True
# 11 : False
# 12 : False
# 13 : True
# 14 : False
# 15 : False
# 16 : False
# 17 : False
# 18 : False
# 19 : True
# 20 : False

# %% [markdown]
# **Testcase 1.**
#
# **Input**: n = 19
#
# **Output**: True
#
# **Explanation**:
#
# $1^2 + 9^2 = 82$
#
# $8^2 + 2^2 = 68$
#
# $6^2 + 2^2 = 100$
#
# $1^2 + 0^2 + 0^2 = 1$

# %% [markdown]
# **Testcase 2.**
#
# **Input**: n = 2
#
# **Output**: False
